# %%
#importing the dataset using Pandas 
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

#reading the data from csv file 
df= pd.read_csv("kc_house_data.csv", encoding="ISO-8859-1")

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
# Looking at first few rows of dataset
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
# Looking at last few rows of dataset
df.tail(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# ...

# %%
# quick grab of data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
#Gives the numbers of rows and columns 
df.shape
# Out:
# (21613, 21)

# %%
#showcase specific informations about a specific column.
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
#Detect missing values.
df.isnull()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21608  False  False  False     False      False        False     False
# 21609  False  False  False     False      False        False     False
# 21610  False  False  False     False      False        False     False
# 21611  False  False  False     False      False        False     False
# 21612  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
#Finding the number of missing values.
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 25 , 15 ) )

    cmap = sns.diverging_palette( 250 , 5 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 11 }


    )
    
plot_correlation_map( df )

# %% [raw]
# I noticed that there is a strong correlation between the price and sqft_living by 0.7, grade by 0.67, sqft_above by 0.61, sqft_living15 by 0.59 and bathrooms by 0.53, also between sqft_living and sqft_above by 0.88, bathrooms by 0.75 and grade by 0.76.

# %%
df['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 8       13
# 0       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
df['bathrooms'].value_counts()
# Out:
# 2.50    5380
# 1.00    3852
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 0.00      10
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 8.00       2
# 6.25       2
# 6.50       2
# 6.75       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
df['grade'].value_counts()
# Out:
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: grade, dtype: int64

# %%
df['condition'].value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
sns.countplot(df.bedrooms,order=df['bedrooms'].value_counts().index)

# %%
plt.hist('sqft_living',data=df,bins=5)
# Out:
# (array([1.825e+04, 3.255e+03, 1.010e+02, 5.000e+00, 2.000e+00]),
#  array([  290.,  2940.,  5590.,  8240., 10890., 13540.]),
#  <a list of 5 Patch objects>)

# %%
plt.scatter(df['sqft_living'], df['price'])
plt.xlabel('sqft_living')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
df = df.drop(df[(df.price > 4000000)].index)
df = df.drop(df[(df.sqft_living > 6000)].index)
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
plt.scatter(df['sqft_living'], df['price'])
plt.xlabel('sqft_living')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
plt.scatter(df['sqft_living'], df['bathrooms'])
plt.xlabel('sqft_living')
plt.ylabel('bathrooms')
# Out:
# Text(0, 0.5, 'bathrooms')

# %%
df = df.drop(df[(df.bathrooms < 1)].index)
df = df.drop(df[(df.bathrooms > 6)].index)
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
plt.scatter(df['sqft_living'], df['bathrooms'])
plt.xlabel('sqft_living')
plt.ylabel('bathrooms')
# Out:
# Text(0, 0.5, 'bathrooms')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.scatter(df['sqft_above'], df['price'])
plt.xlabel('sqft_above')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
plt.scatter(df['grade'], df['price'])
plt.xlabel('grade')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
df = df.drop(df[(df.grade > 12)].index)
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
plt.scatter(df['grade'], df['price'])
plt.xlabel('grade')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
plt.scatter(df['bathrooms'], df['price'])
plt.xlabel('bathrooms')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
#extract sqft_living and price from our data : df
x=df["sqft_living"].values[:,np.newaxis]
y=df["price"].values

#x=df[["sqft_living"]]
#y=df[["price"]]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=30) #splitting data with test size of 30%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 57107852994.63807
# R squared 0.4674244414980946

# %%
print('R squared training',round(model.score(x_train,y_train),3))
print('R sqaured testing',round(model.score(x_test,y_test),3) )
print('intercept',model.intercept_)
print('coefficient',model.coef_)
# Out:
# R squared training 0.458
# R sqaured testing 0.467
# intercept -13890.146237295121
# coefficient [264.65113788]

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
#extract x and y from our data
x=df[["sqft_living","bathrooms"]]  #we have more than one input
y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=30) #splitting data with test size of 30%

model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 57106273418.91422
# R squared 0.4674391722816771

# %%
print('R squared training',round(model.score(x_train,y_train),3))
print('R sqaured testing',round(model.score(x_test,y_test),3) )
print('intercept',model.intercept_)
print('coefficient',model.coef_)
# Out:
# R squared training 0.458
# R sqaured testing 0.467
# intercept -15194.036273322185
# coefficient [ 263.59364815 1651.40312368]

# %%
#extract x and y from our data
x=df[["sqft_living","bedrooms"]]  #we have more than one input
y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=30) #splitting data with test size of 30%

model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 56579569163.35027
# R squared 0.47235110292453697

# %%
print('R squared training',round(model.score(x_train,y_train),3))
print('R sqaured testing',round(model.score(x_test,y_test),3) )
print('intercept',model.intercept_)
print('coefficient',model.coef_)
# Out:
# R squared training 0.473
# R sqaured testing 0.472
# intercept 107226.28998676932
# coefficient [   299.28741496 -57206.99672028]

# %% [raw]
# The correlation of linear regression is very close to the correlation of multilinear regression :
# in linear regression :
# x=df["sqft_living"].values[:,np.newaxis]
# y=df["price"].values
#
# R squared training 0.458
# R sqaured testing 0.467
# intercept -13890.146237295121
# coefficient [264.65113788]
#
#
# In Multiple Regression :
# 1st case :
# x=df[["sqft_living","bathrooms"]]
# y=df["price"].values
#
# R squared training 0.458
# R sqaured testing 0.467
# intercept -15194.036273322185
# coefficient [ 263.59364815 1651.40312368]
#
#
# 2nd case:
# x=df[["sqft_living","bedrooms"]]
# y=df["price"].values
#
# R squared training 0.473
# R sqaured testing 0.472
# intercept 107226.28998676932
# coefficient [   299.28741496 -57206.99672028]

# %%
plt.figure(figsize=(12, 4))

predictors = ['sqft_living', 'bedrooms','bathrooms']
target = df['price']

for i, col in enumerate(predictors):
    plt.subplot(1, len(predictors) , i+1)
    x = df[col]
    y = target
    plt.scatter(x, y, marker='o')
    plt.title(col)
    plt.xlabel(col)
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
#Importing libraries

from sklearn.preprocessing import PolynomialFeatures 

from sklearn.metrics import mean_squared_error
from sklearn import metrics


# create matrix and vectors

x=df[["sqft_living","bedrooms"]]  #we have more than one input
y=df["price"].values


lg = LinearRegression() 
poly = PolynomialFeatures(degree = 2)

# %%
x_=poly.fit_transform(x)

# %%
x_=poly.fit_transform(x)
print("x before transformation: ", x)
print("x after transformation: ", x_)
lg.fit(x_, y) # Fitting Polynomial Regression to the dataset
# Out:
# x before transformation:         sqft_living  bedrooms
# 0             1180         3
# 1             2570         3
# 2              770         2
# 3             1960         4
# 4             1680         3
# ...            ...       ...
# 21606         3510         4
# 21607         1310         3
# 21608         1530         3
# 21609         2310         4
# 21611         1600         3
#
# [21455 rows x 2 columns]
# x after transformation:  [[1.0000e+00 1.1800e+03 3.0000e+00 1.3924e+06 3.5400e+03 9.0000e+00]
#  [1.0000e+00 2.5700e+03 3.0000e+00 6.6049e+06 7.7100e+03 9.0000e+00]
#  [1.0000e+00 7.7000e+02 2.0000e+00 5.9290e+05 1.5400e+03 4.0000e+00]
#  ...
#  [1.0000e+00 1.5300e+03 3.0000e+00 2.3409e+06 4.5900e+03 9.0000e+00]
#  [1.0000e+00 2.3100e+03 4.0000e+00 5.3361e+06 9.2400e+03 1.6000e+01]
#  [1.0000e+00 1.6000e+03 3.0000e+00 2.5600e+06 4.8000e+03 9.0000e+00]]
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x=df[["sqft_living"]]  #we have more than one input
y=df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=30)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  54448983007.29921
# R squared:  0.4922204913272469

# %%
print('intercept',model.intercept_)
print('coefficient',model.coef_)
# Out:
# intercept 107226.28998676932
# coefficient [   299.28741496 -57206.99672028]

# %%
x= df["sqft_living"].values.reshape(-1,1)
y=df["price"].values
poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="r")
plt.title("Linear regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")

# %% [raw]
# The correlation of the polynomial regression is higher than the correlation of the linear regression:
# in linear regression :
# x=df["sqft_living"].values[:,np.newaxis]
# y=df["price"].values
#
# R sqaured testing 0.467
# intercept -13890.146237295121
# coefficient [264.65113788]
#
# In polynomial regression:
# R sqaured testing 0.492
# intercept 107226.28998676932
# coefficient [   299.28741496 -57206.99672028]
